# %% [markdown]
# # Hypothesis Testing

# %%
# Importing required packages

import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm          # A normal continuous random variable
from numpy.random import seed         # set the randomness
from scipy import stats               # statistical operations
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### One-Sample Z-Test for Mean

# %% [markdown]
# Let's create some dummy age data for the population of voters in the entire country and a sample of voters in North_Carolina and test whether the average age of voters in North_Carolina differs from the entire country population.
#
# .rvs provides random samples; scale = std. deviation, loc = mean, size = no. of samples

# %%
# Generate Population ages data

np.random.seed(6)

population_ages1 = stats.norm.rvs(scale=18, loc=45, size=150000)
population_ages2 = stats.norm.rvs(scale=18, loc=20, size=100000)
population_ages = np.concatenate((population_ages1, population_ages2))

# Generate North Carolina sample ages data

North_Carolina_ages1 = stats.norm.rvs(scale=18, loc=40, size=30)
North_Carolina_ages2 = stats.norm.rvs(scale=18, loc=20, size=25)
North_Carolina_ages = np.concatenate((North_Carolina_ages1, North_Carolina_ages2))

print("Mean age of population of voters in the entire country: ", population_ages.mean())
print("Mean age of North Carolina population: ", North_Carolina_ages.mean())
# Out:
# Mean age of population of voters in the entire country:  34.97043368335889
# Mean age of North Carolina population:  28.52661116077034

# %% [markdown]
# Notice that we used a slightly different combination of distributions to generate the sample data for North_Carolina, so we know that the two means are different. Let's conduct a z-test at a 95% confidence level and see if it correctly rejects the null hypothesis that the sample comes from the same distribution as the population.

# %%
# Perform Z-test for mean
one_sample_ztest = sm.stats.ztest(x1= North_Carolina_ages, x2=None, value= population_ages.mean(), alternative='smaller')

print("test-statistic (z-score): ", one_sample_ztest[0])
print("p-value: ", one_sample_ztest[1])
# Out:
# test-statistic (z-score):  -2.2814904209459996
# p-value:  0.011259721451099942

# %% [markdown]
# The z-score tells us how many standard deviations from the mean our score is. In this example, our score is -2.28 standard deviations below the mean. Also, we can reject the null hypothesis that the mean of samples is equal to the population mean (i.e. 28.52) as we can see that the p-value is less than 0.05 (i.e. 0.011). This indicates that the difference between the sample mean and population mean is statistically significant.

# %% [markdown]
# ### Two-Sample Z-Test for Mean

# %% [markdown]
# Let's create a sample of voters in South_Carolina and test whether the average age of voters in North_Carolina differs from the average age of voters in South_Carolina.

# %%
np.random.seed(12)

# Generate South Carolina sample ages data
South_Carolina_ages1 = stats.norm.rvs(scale=15, loc=33, size=30)
South_Carolina_ages2 = stats.norm.rvs(scale=15, loc=20, size=25)
South_Carolina_ages = np.concatenate((South_Carolina_ages1, South_Carolina_ages2))

print("Mean age of South Carolina population: ", South_Carolina_ages.mean())
# Out:
# Mean age of South Carolina population:  24.970648445336874

# %%
# Perform Two sample Z-test for Mean
two_sample_ztest = sm.stats.ztest(x1=North_Carolina_ages, x2=South_Carolina_ages, value=0, alternative='two-sided')
print("test-statistic (z-score): ", two_sample_ztest[0])
print("p-value: ", two_sample_ztest[1])
# Out:
# test-statistic (z-score):  0.9604812179337472
# p-value:  0.3368130793371993

# %% [markdown]
# The test yields a p-value of 0.336, which means there is a 33.6% chance we'd see the difference in the means of the two sample data are not equal to value (here, it is 0 as here we calculate the difference of the two sample means), if these two groups tested are actually identical. If we were using a 95% confidence level we would fail to reject the null hypothesis, since the p-value is greater than the corresponding significance level of 5%.

# %% [markdown]
# ### Paired Z-Test for Mean

# %% [markdown]
# Consider the weights of a group of patients before and after an exercise program.
#
# * Observation 1: The weight of a group of patients was evaluated at baseline.
# * Observation 2: This same group of patients was evaluated after an 8-week exercise program.
# * Variable of interest: Body weight.
#
# In this example, we have one group with two observations, meaning that the data are paired. In this example, we know the population variance of body weights of each patient from previous studies.
#
# The null hypothesis is that there will be no difference in weights measured before and after the exercise program. After observing that our data meet the assumptions of a paired samples z-test (the variable of interest is continuous, it has only two groups i.e. two measurements from a single group, it has paired samples, it has a normal variable of interest and the population variance is known), we proceed with the analysis.
#
# When we run the analysis, we get a test statistic (in this case a Z-statistic) and a p-value.
#
# The test statistic is a measure of how different the group is on our body weight variable of interest across the two observations.
# The p-value is the chance of seeing our results assuming the exercise program actually doesn’t do anything. A p-value less than or equal to 0.05 means that our result is statistically significant and we can trust that the difference is not due to chance alone.

# %%
np.random.seed(11)

# Generate Weights of population before exercise program
before = stats.norm.rvs(scale=10, loc=50, size=100)

# Generate Weights of population after exercise program
after = before + stats.norm.rvs(scale=5, loc=-3.5, size=100)

# Create dataframe
weight_df = pd.DataFrame({"weight_before":before, "weight_after":after, "weight_change":after-before})

weight_df.head()
# Out:
#    weight_before  weight_after  weight_change
# 0      67.494547     68.365911       0.871364
# 1      47.139270     43.997531      -3.141739
# 2      45.154349     33.459091     -11.695258
# 3      23.466814     16.730301      -6.736513
# 4      49.917154     50.506002       0.588848

# %%
# Check summary of the data
weight_df.describe()
# Out:
#        weight_before  weight_after  weight_change
# count     100.000000    100.000000     100.000000
# mean       50.115182     46.634807      -3.480375
# std         9.377513     10.423714       4.783696
# min        23.466814     16.730301     -13.745286
# 25%        43.473681     39.362388      -6.296211
# 50%        50.276935     47.179677      -3.663463
# 75%        56.879048     53.765628      -0.511327
# max        71.566744     71.336869       7.509282

# %% [markdown]
# The summary shows that patients lost about 3.48 pounds on average after the exercise program. Let's conduct a paired z-test to see whether this difference is significant at a 95% confidence level

# %%
# Perform paired Z-test
pair_ztest = sm.stats.ztest(x1=before, x2=after, value=0, alternative='two-sided')
print("test-statistic: ", pair_ztest[0])
print("p-value: ", pair_ztest[1])
# Out:
# test-statistic:  2.48223901119329
# p-value:  0.013055966969698763

# %% [markdown]
# Here the null-hypothesis was that in the population (from which the samples are drawn) the difference between similarly paired observations is 0 (as indicated by value = 0). The p-value in the test output shows that the probability that the difference in means is not equal to the value (0) is 1.3%, i.e. < 5%, so the null hypothesis is rejected. The differences in means of the weight measurements before and after the exercise program is statistically significant.

# %% [markdown]
# ### Two Sample T-test for Mean

# %% [markdown]
# Consider the Professional Salary Survey Results dataset. At  α  = 0.05, test whether the salary means for both male and female employees for the year 2019 who belong to the United States, are equal.
#
# The corresponding null hypothesis and alternate hypothesis are as follows:
#
# * $H_0$ : both salary means( male and female) are equal
# * $H_A$ : both means are not equal
#
# Now, we will carry out the two-sample t-test

# %%
raw_data = pd.read_csv('2019_Data_Professional_Salary_Survey_Responses.csv', header=3)
raw_data.head()
# Out:
#    Survey Year         Timestamp SalaryUSD         Country PostalCode  \
# 0         2017  1/5/2017 5:10:20    200000   United States  Not Asked
# 1         2017  1/5/2017 5:26:23     61515  United Kingdom  Not Asked
# 2         2017  1/5/2017 5:32:57     95000         Germany  Not Asked
# 3         2017  1/5/2017 5:33:03     56000  United Kingdom  Not Asked
# 4         2017  1/5/2017 5:34:34     35000          France  Not Asked
#
#         PrimaryDatabase  YearsWithThisDatabase  \
# 0  Microsoft SQL Server                     10
# 1  Microsoft SQL Server                     15
# 2  Microsoft SQL Server                      5
# 3  Microsoft SQL Server                      6
# 4  Microsoft SQL Server                     10
#
#                     OtherDatabases  \
# 0                    MySQL/MariaDB
# 1               Oracle, PostgreSQL
# 2  Oracle, MySQL/MariaDB, Informix
# 3                              NaN
# 4                           Oracle
#
#                                     EmploymentStatus JobTitle  ...  \
# 0                                 Full time employee      DBA  ...
# 1                                 Full time employee      DBA  ...
# 2                                 Full time employee    Other  ...
# 3                                 Full time employee      DBA  ...
# 4  Full time employee of a consulting/contracting...      DBA  ...
#
#   HoursWorkedPerWeek             TelecommuteDaysPerWeek  \
# 0                 45                                  1
# 1                 35                                  2
# 2                 45  None, or less than 1 day per week
# 3                 40                                  1
# 4                 40  None, or less than 1 day per week
#
#   PopulationOfLargestCityWithin20Miles  EmploymentSector  \
# 0                            Not Asked  Private business
# 1                            Not Asked  Private business
# 2                            Not Asked  Private business
# 3                            Not Asked  Private business
# 4                            Not Asked  Private business
#
#                      LookingForAnotherJob  CareerPlansThisYear     Gender  \
# 0  Yes, but only passively (just curious)            Not Asked  Not Asked
# 1                                      No            Not Asked  Not Asked
# 2  Yes, but only passively (just curious)            Not Asked  Not Asked
# 3  Yes, but only passively (just curious)            Not Asked  Not Asked
# 4  Yes, but only passively (just curious)            Not Asked  Not Asked
#
#   OtherJobDuties KindsOfTasksPerformed  Counter
# 0      Not Asked             Not Asked        1
# 1      Not Asked             Not Asked        1
# 2      Not Asked             Not Asked        1
# 3      Not Asked             Not Asked        1
# 4      Not Asked             Not Asked        1
#
# [5 rows x 29 columns]

# %%
raw_data.shape
# Out:
# (6893, 29)

# %%
len(raw_data)
# Out:
# 6893

# %%
# Check for missing values
raw_data.isna().sum() / len(raw_data)
# Out:
# Survey Year                             0.000000
# Timestamp                               0.000000
# SalaryUSD                               0.000000
# Country                                 0.000000
# PostalCode                              0.139127
# PrimaryDatabase                         0.000000
# YearsWithThisDatabase                   0.000000
# OtherDatabases                          0.199188
# EmploymentStatus                        0.000000
# JobTitle                                0.000000
# ManageStaff                             0.000000
# YearsWithThisTypeOfJob                  0.000000
# HowManyCompanies                        0.000000
# OtherPeopleOnYourTeam                   0.389961
# CompanyEmployeesOverall                 0.000000
# DatabaseServers                         0.000000
# Education                               0.000000
# EducationIsComputerRelated              0.176411
# Certifications                          0.000000
# HoursWorkedPerWeek                      0.000000
# TelecommuteDaysPerWeek                  0.000000
# PopulationOfLargestCityWithin20Miles    0.000000
# EmploymentSector                        0.000000
# LookingForAnotherJob                    0.000000
# CareerPlansThisYear                     0.000000
# Gender                                  0.000000
# OtherJobDuties                          0.089946
# KindsOfTasksPerformed                   0.030030
# Counter                                 0.000000
# dtype: float64

# %%
# Remove missing values
raw_data.dropna(inplace=True)
raw_data.reset_index(drop= True, inplace= True)
raw_data.isna().sum()  #to check there are no more missing values
# Out:
# Survey Year                             0
# Timestamp                               0
# SalaryUSD                               0
# Country                                 0
# PostalCode                              0
# PrimaryDatabase                         0
# YearsWithThisDatabase                   0
# OtherDatabases                          0
# EmploymentStatus                        0
# JobTitle                                0
# ManageStaff                             0
# YearsWithThisTypeOfJob                  0
# HowManyCompanies                        0
# OtherPeopleOnYourTeam                   0
# CompanyEmployeesOverall                 0
# DatabaseServers                         0
# Education                               0
# EducationIsComputerRelated              0
# Certifications                          0
# HoursWorkedPerWeek                      0
# TelecommuteDaysPerWeek                  0
# PopulationOfLargestCityWithin20Miles    0
# EmploymentSector                        0
# LookingForAnotherJob                    0
# CareerPlansThisYear                     0
# Gender                                  0
# OtherJobDuties                          0
# KindsOfTasksPerformed                   0
# Counter                                 0
# dtype: int64

# %%
# Data type of SalaryUSD column
raw_data['SalaryUSD'].dtype
# Out:
# dtype('O')

# %%
# Unique values of SalaryUSD column
raw_data['SalaryUSD'].unique()
# Out:
# array(['200000', '95000', '47000', '41000', '51652', '63000', '45000',
#        '123000', '80000', '102000', '107690', '84000', '120000', '140000',
#        '138000', '40000', '72800', '99000', '50000', '55000', '175000',
#        '113400', '97500', '17621', '105000', '85000', '104000', '98000',
#        '70760', '67770', '82000', '98517', '107000', '78000', '72000',
#        '125000', '67000', '129000', '66000', '121000', '10000', '15000',
#        '130000', '87000', '70000', '35900', '61606', '96000', '27000',
#        '35000', '50400', '160000', '115000', '7968', '138500', '63500',
#        '88000', '111000', '134000', '95500', '100000', '122000', '26000',
#        '14000', '112500', '12000', '12900', '110000', '53000', '113000',
#        '90000', '93000', '94000', '65000', '92000', '120792', '145000',
#        '93800', '93500', '270000', '108000', '117000', '118500', '165000',
#        '73000', '109000', '62000', '70400', '153000', '116000', '149000',
#        '75000', '76000', '142500', '98600', '62666', '146000', '148000',
#        '115544', '77000', '97000', '69725', '91520', '20000', '56000',
#        '89500', '112350', '55670', '137000', '81000', '150000', '53343',
#        '74424', '135000', '67418', '127500', '87491', '40100', '56140',
#        '102500', '83000', '145493', '16000', '86000', '127000', '64000',
#        '76800', '36000', '272000', '90756', '225000', '62391', '69000',
#        '25000', '3900', '106000', '71500', '89000', '112000', '68310',
#        '97325', '133000', '139000', '147500', '94500', '47500', '114000',
#        '42000', '143000', '103000', '92600', '8400', '105750', '142000',
#        '77250', '43000', '29148', '131000', '80751', '36400', '156000',
#        '151000', '26300', '74000', '23000', '49900', '101000', '124600',
#        '170000', '77500', '163000', '1450000', '80080', '67902', '60000',
#        '196000', '69508', '74104', '136000', '22000', '71000', '11300',
#        '30500', '4420', '54500', '253000', '5500', '117600', '51500',
#        '79000', '11000', '18000', '1600', '1250', '29000', '6200',
#        '25500', '11119', '22941', '68000', '41333', '60300', '61000',
#        '37166', '59000', '66400', '63176', '31000', '7650', '21350',
#        '34375', '35577', '4118', '545', '15500', '8200', '141000',
#        '132000', '44000', '84500', '27260', '30000', '42400', '17647',
#        '180000', '74351', '115600', '24000', '58000', '124000', '104300',
#        '87400', '300000', '55300', '55700', '13455', '71300', '48000',
#        '38000', '39566', '76500', '13000', '65500', '32000', '8500',
#        '37400', '51000', '11500', '165227', '5000', '62250', '74500',
#        '14500', '62109', '52382', '85232', '133615', '53300', '40300',
#        '51101', '98304', '43800', '111500', '195000', '121500', '176000',
#        '100400', '73757', '3000', '98750', '39000', '57000', '368900',
#        '64480', '27880', '250000', '128000', '88500', '75600', '123200',
#        '73014', '18500', '120250', '92500', '155000', '162000', '29500',
#        '64300', '87500', '73800', '64280', '43758', '49000', '49500',
#        '45408', '87890', '154000', '100318', '400000', '33500', '64460',
#        '52000', '81723', '185000', '144000', '91000', '95800', '94200',
#        '106700', '78245', '118000', '69882', '26500', '91500', '210000',
#        '1467', '12600', '41200', '52970', '44636', '290000', '72500',
#        '52270', '147000', '2000', '20500', '87992', '76200', '24265',
#        '10256', '575000', '96500', '10900', '72730', '113842', '10073',
#        '81100', '51284', '8000', '23300', '56173', '143200', '11745',
#        '121807', '20290', '58560', '110154', '114300', '31017', '126000',
#        '92822', '86700', '32800', '100646', '21000', '63600', '172000',
#        '95,000', '96,000', '155,000', '44.806', '125,000', '64186',
#        '84154', '111300', '65995', '97,000', '110,000', '106500',
#        '122800', '133,000', '110724', '85850', '120,000', '50085',
#        '85,000', '100,000', '52,490', '160750', '91400', '116400',
#        '74200', '108819', '145,000', '108,000', '58,000', '97335',
#        '184000', '117500', '115,000', '113900', '54000', '117,500',
#        '135,500', '105,000', '92,000', '108564', '91,000', '49230',
#        '55500', '135,000', '220000', '130,000', '104,500', '78,000',
#        '118560', '5214', '60,000', '29260', '72,000', '102456', '48125',
#        '107,000', '89139', '148986', '155500', '16700', '46000',
#        '102,494', '137,000', '71,000', '67,164', '$105,000', '2246',
#        '92750', '192000', '30,000', '116,000', '54600', '45,000',
#        '190000', '115500', '61500', '58750', '41404', '90,000', '111,250',
#        '129,000', '53,040', '57,000', '193,000', '114,000', '104,000',
#        '90937', '147,000', '90875', '81,000', '123,000', '56800',
#        '56,000', '94188', '72,500', '122400', '65,500', '141,000.00',
#        '52,000', '22735', '57200', '37100', '31893', '50,000', '47219.2',
#        '150,000', '56', '44,000', '75110', '80200', '94,000', '87600',
#        '7500', '83234', '121,000', '100500', '61562', '56900', '10650',
#        '46500', '54952', '87100', '113650', '75,000', '135300', '80100',
#        '65700', '70,000', '115,000.00', '62,000', '80,000', '140,000',
#        '152000', '164000', '75524', '75200', '45500', '83500', '132131',
#        '149,000', '101725', '128,500', '84,000', '164,000', '98,000',
#        '82500', '113,000', '59500', '260000', '144,000', '10962', '41124',
#        '5800', '87.83', '138,000', '37538', '33,437', '144700', '67,000',
#        '90900', '110040', '143,000', '47573.49', '73500', '15600',
#        '116340', '133,817', '157000', '77,000', '107500', '133010',
#        '60332', '109500', '140,394', '345000', '52256', '9360', '53460',
#        '73,840', '10095', '188000', '54,000', '6260', '74422', '67700',
#        '90500', '198000', '101,000', '142600', '151400', '65,543',
#        '46350', '109200', '28,000', '63,800', '82,000', '110,240.00',
#        '124500', '68,000', '69086', '87,400', '119000', '128500',
#        '240000', '500000', '119500', '158500', '70180', '85654', '129800',
#        '78052', '11800', '45170', '50140', '65180', '130090', '80104',
#        '61903', '78600', '54772', '2400', '11100', '77700', '67500',
#        '79800', '37500', '83200', '205000', '61200', '77850', '41300',
#        '275000', '69610', '61400', '60750', '85200', '29200', '127750',
#        '71400', '113100', '69500', '58500'], dtype=object)

# %%
# Processing Salary column

def process_salary(salary):
    sep = '.'
    salary = str(salary)
    # Replace characters and take the cents out of our data
    salary = salary.replace(" ","").replace("$","").replace(",","").split(sep)[0]

    return float(salary)

# Replace spaces(“ “) in columns name with underscore (“_”)
raw_data.columns = raw_data.columns.str.replace(" ","_")

# Apply process_salary function
raw_data['SalaryUSD'] = raw_data['SalaryUSD'].apply(process_salary)
raw_data['SalaryUSD'].head()
# Out:
# 0    200000.0
# 1     95000.0
# 2     47000.0
# 3     41000.0
# 4     51652.0
# Name: SalaryUSD, dtype: float64

# %%
# Filter dataframe by year
df = raw_data[raw_data.Survey_Year == 2019]
df.head()
# Out:
#       Survey_Year           Timestamp  SalaryUSD        Country PostalCode  \
# 1935         2019  12/6/2018 13:58:02   128500.0  United States        442
# 1936         2019  12/11/2018 6:24:30   110000.0  United States      43016
# 1937         2019  12/11/2018 6:33:56   124000.0  United States      92105
# 1938         2019  12/11/2018 6:38:03   115000.0  United States        494
# 1939         2019  12/11/2018 6:46:05   115000.0  United States      43016
#
#            PrimaryDatabase  YearsWithThisDatabase  \
# 1935  Microsoft SQL Server                     15
# 1936  Microsoft SQL Server                     18
# 1937  Microsoft SQL Server                     18
# 1938  Microsoft SQL Server                     14
# 1939  Microsoft SQL Server                     15
#
#                                          OtherDatabases    EmploymentStatus  \
# 1935                       Microsoft SQL Server, Oracle  Full time employee
# 1936                                       Azure SQL DB  Full time employee
# 1937                                             Oracle  Full time employee
# 1938  Microsoft SQL Server, Elasticsearch, Azure SQL DB  Full time employee
# 1939                                       Azure SQL DB  Full time employee
#
#                                                JobTitle  ...  \
# 1935                                          Architect  ...
# 1936  DBA (Development Focus - tunes queries, indexe...  ...
# 1937  DBA (General - splits time evenly between writ...  ...
# 1938  DBA (Development Focus - tunes queries, indexe...  ...
# 1939  DBA (Development Focus - tunes queries, indexe...  ...
#
#      HoursWorkedPerWeek             TelecommuteDaysPerWeek  \
# 1935                 40  None, or less than 1 day per week
# 1936                 44  None, or less than 1 day per week
# 1937                 40                                  4
# 1938                 45                                  4
# 1939                 55  None, or less than 1 day per week
#
#      PopulationOfLargestCityWithin20Miles  EmploymentSector  \
# 1935                 300K-1M (large city)  Private business
# 1936                     1M+ (metropolis)  Private business
# 1937                     1M+ (metropolis)  Private business
# 1938                     100K-299K (city)  Private business
# 1939                 300K-1M (large city)  Private business
#
#                           LookingForAnotherJob  \
# 1935                                        No
# 1936                                        No
# 1937  Yes, actively looking for something else
# 1938  Yes, actively looking for something else
# 1939    Yes, but only passively (just curious)
#
#                                 CareerPlansThisYear Gender  \
# 1935         Stay with the same employer, same role   Male
# 1936         Stay with the same employer, same role   Male
# 1937  Stay with the same role, but change employers   Male
# 1938  Stay with the same role, but change employers   Male
# 1939         Stay with the same employer, same role   Male
#
#                                          OtherJobDuties  \
# 1935  DBA (Development Focus - tunes queries, indexe...
# 1936  DBA (Production Focus - build & troubleshoot s...
# 1937  DBA (Development Focus - tunes queries, indexe...
# 1938  DBA (Production Focus - build & troubleshoot s...
# 1939  Architect, DBA (Production Focus - build & tro...
#
#                                   KindsOfTasksPerformed  Counter
# 1935      Manual tasks, Meetings & management, Projects        1
# 1936  Build scripts & automation tools, Manual tasks...        1
# 1937                        Manual tasks, Projects, R&D        1
# 1938  Meetings & management, On-call as part of a ro...        1
# 1939  On-call as part of a rotation, Projects, R&D, ...        1
#
# [5 rows x 29 columns]

# %%
# Filter dataframe by country
US_2019 = df.loc[df.Country == 'United States', :]
US_2019.head(3)
# Out:
#       Survey_Year           Timestamp  SalaryUSD        Country PostalCode  \
# 1935         2019  12/6/2018 13:58:02   128500.0  United States        442
# 1936         2019  12/11/2018 6:24:30   110000.0  United States      43016
# 1937         2019  12/11/2018 6:33:56   124000.0  United States      92105
#
#            PrimaryDatabase  YearsWithThisDatabase  \
# 1935  Microsoft SQL Server                     15
# 1936  Microsoft SQL Server                     18
# 1937  Microsoft SQL Server                     18
#
#                     OtherDatabases    EmploymentStatus  \
# 1935  Microsoft SQL Server, Oracle  Full time employee
# 1936                  Azure SQL DB  Full time employee
# 1937                        Oracle  Full time employee
#
#                                                JobTitle  ...  \
# 1935                                          Architect  ...
# 1936  DBA (Development Focus - tunes queries, indexe...  ...
# 1937  DBA (General - splits time evenly between writ...  ...
#
#      HoursWorkedPerWeek             TelecommuteDaysPerWeek  \
# 1935                 40  None, or less than 1 day per week
# 1936                 44  None, or less than 1 day per week
# 1937                 40                                  4
#
#      PopulationOfLargestCityWithin20Miles  EmploymentSector  \
# 1935                 300K-1M (large city)  Private business
# 1936                     1M+ (metropolis)  Private business
# 1937                     1M+ (metropolis)  Private business
#
#                           LookingForAnotherJob  \
# 1935                                        No
# 1936                                        No
# 1937  Yes, actively looking for something else
#
#                                 CareerPlansThisYear Gender  \
# 1935         Stay with the same employer, same role   Male
# 1936         Stay with the same employer, same role   Male
# 1937  Stay with the same role, but change employers   Male
#
#                                          OtherJobDuties  \
# 1935  DBA (Development Focus - tunes queries, indexe...
# 1936  DBA (Production Focus - build & troubleshoot s...
# 1937  DBA (Development Focus - tunes queries, indexe...
#
#                                   KindsOfTasksPerformed  Counter
# 1935      Manual tasks, Meetings & management, Projects        1
# 1936  Build scripts & automation tools, Manual tasks...        1
# 1937                        Manual tasks, Projects, R&D        1
#
# [3 rows x 29 columns]

# %%
# Number of employees by their genders
US_2019.Gender.value_counts()
# Out:
# Gender
# Male      170
# Female     16
# Name: count, dtype: int64

# %%
# Filter salary by gender
Male_salary = US_2019[US_2019.Gender == 'Male']['SalaryUSD']
Female_salary = US_2019[US_2019.Gender == 'Female']['SalaryUSD']

print("Mean salary for male employees: ", Male_salary.mean())
print("Mean salary for female employees: ", Female_salary.mean())
# Out:
# Mean salary for male employees:  107485.23529411765
# Mean salary for female employees:  95481.25

# %%
# Perform t-test on data
ttest = stats.ttest_ind(a = Female_salary, b = Male_salary, equal_var= False)
ttest
# Out:
# TtestResult(statistic=np.float64(-1.2238287711542442), pvalue=np.float64(0.23553795212550016), df=np.float64(19.583191021914505))
